# %% [markdown]
# <a href="https://colab.research.google.com/github/jbsdoki/ML_trader/blob/main/Sentiment_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install torch -q
# !pip install transformers -q

from transformers import AutoTokenizer, AutoModelForSequenceClassification, pipeline

# %%
model_name = "ProsusAI/finbert"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSequenceClassification.from_pretrained(model_name)

# %%
# Initialize the sentiment analysis pipeline
nlp = pipeline("sentiment-analysis", model=model, tokenizer=tokenizer)

# %%
# Example sentences for testing
sentences = [
    "there is a shortage of capital, and we need extra financing",
    "growth is strong and we have plenty of liquidity",
    "there are doubts about our finances",
    "profits are flat"
]

# Get results
results = nlp(sentences)
print(results)
# Out:
# [{'label': 'negative', 'score': 0.8653576970100403}, {'label': 'positive', 'score': 0.9025793075561523}, {'label': 'neutral', 'score': 0.45697399973869324}, {'label': 'neutral', 'score': 0.7185565829277039}]
